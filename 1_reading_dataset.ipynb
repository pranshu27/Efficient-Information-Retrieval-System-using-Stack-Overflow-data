# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
import nltk
import warnings
warnings.filterwarnings('ignore')
import logging
logging.getLogger("lda").setLevel(logging.WARNING)
try:
  nltk.download('stopwords')
except:
  pass
try:
  nltk.download('punkt')
except:
  pass
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Utkarsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Utkarsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ##### Import stopwords

# %%
stopwords = stopwords.words('english')

# %% [markdown]
# ## Reading Questions.csv

# %%
df_questions = pd.read_csv("Questions.csv",usecols=['Id', 'CreationDate', 'Score', 'Title','Body'], encoding='latin1')
df_questions = df_questions.dropna()
df_questions.head()
# Out:
#     Id          CreationDate  Score  \
# 0   80  2008-08-01T13:57:07Z     26
# 1   90  2008-08-01T14:41:24Z    144
# 2  120  2008-08-01T15:50:08Z     21
# 3  180  2008-08-01T18:42:19Z     53
# 4  260  2008-08-01T23:22:08Z     49
#
#                                                Title  \
# 0  SQLStatement.execute() - multiple queries in o...
# 1  Good branching and merging tutorials for Torto...
# 2                                  ASP.NET Site Maps
# 3                 Function for creating color wheels
# 4  Adding scripting functionality to .NET applica...
#
#                                                 Body
# 0  <p>I've written a database generation script i...
# 1  <p>Are there any really good tutorials explain...
# 2  <p>Has anyone got experience creating <strong>...
# 3  <p>This is something I've pseudo-solved many t...
# 4  <p>I have a little game written in C#. It uses...

# %% [markdown]
# ## Reading Answers.csv

# %%
df_answers = pd.read_csv("Answers.csv",usecols = ['ParentId','Score','Body'], encoding='latin1')
df_answers.columns = ['Id','Answer_Score','Answer_Body']
df_answers
# Out:
#                Id  Answer_Score  \
# 0              90            13
# 1              80            12
# 2             180             1
# 3             260             4
# 4             260            28
# ...           ...           ...
# 2014511  40143190             0
# 2014512  40137110             1
# 2014513  40141860             0
# 2014514  40077010             0
# 2014515  40142910             0
#
#                                                Answer_Body
# 0        <p><a href="http://svnbook.red-bean.com/">Vers...
# 1        <p>I wound up using this. It is a kind of a ha...
# 2        <p>I've read somewhere the human eye can't dis...
# 3        <p>Yes, I thought about that, but I soon figur...
# 4        <p><a href="http://www.codeproject.com/Article...
# ...                                                    ...
# 2014511  <p>Tanks to <a href="http://stackoverflow.com/...
# 2014512  <h1>tl;dr</h1>\n\n<pre><code>ZonedDateTime.par...
# 2014513  <p>I came up with a very dirty workaround. Bef...
# 2014514  <p>I solved my own problem defining the follow...
# 2014515  <p>Try add <code>retrun false</code> in the <c...
#
# [2014516 rows x 3 columns]

# %% [markdown]
# ## Reading Tags.csv

# %%
df_tags = pd.read_csv("Tags.csv" ,encoding='latin1')
df_tags
# Out:
#                Id             Tag
# 0              80            flex
# 1              80  actionscript-3
# 2              80             air
# 3              90             svn
# 4              90     tortoisesvn
# ...           ...             ...
# 3750989  40143360      javascript
# 3750990  40143360          vue.js
# 3750991  40143380             npm
# 3750992  40143380           mocha
# 3750993  40143380           babel
#
# [3750994 rows x 2 columns]

# %% [markdown]
# ## Preprocessing Datasets

# %% [markdown]
# ### 1. Define functions

# %% [markdown]
# #####  Normalize Text: normalize_text() to remove tags of html and codes etc

# %%
def normalize_text(text):
    tm1 = re.sub('<pre>.*?</pre>', '', text, flags=re.DOTALL)
    tm2 = re.sub('<code>.*?</code>', '', tm1, flags=re.DOTALL)
    tm3 = re.sub('<[^>]+>', '', tm2, flags=re.DOTALL)
    x = tm3.replace("\n", "")
    return x

# %% [markdown]
# #### Remove Stopwords and Punctuations: remove_stopwords_punctuations() to remove them

# %%
def remove_stopwords_punctuations(text):
    #REmove punctuations ~30 seconds
    text = text.replace(r'[^\w\s]+', '')
    # remove stopwords ~4 minutes
    text = ' '.join([word for word in text.split() if word not in (stopwords)])
    return text

# %% [markdown]
# #### Concatenate multiple tags: same question having multiple tags is handled

# %%
def concatenate_multiple_tags(df):
    df = df.groupby('Id', as_index=False).agg({'Tag' : ','.join})
    return df

# %% [markdown]
# ### 2. Application of preprocessing functions on datasets

# %% [markdown]
# #### on Questions.csv

# %%
df_questions['Body'] = df_questions['Body'].apply(lambda x: normalize_text(x))
df_questions['Body'] = df_questions['Body'].apply(lambda x: remove_stopwords_punctuations(x))
df_questions
# Out:
#                Id          CreationDate  Score  \
# 0              80  2008-08-01T13:57:07Z     26
# 1              90  2008-08-01T14:41:24Z    144
# 2             120  2008-08-01T15:50:08Z     21
# 3             180  2008-08-01T18:42:19Z     53
# 4             260  2008-08-01T23:22:08Z     49
# ...           ...                   ...    ...
# 1264211  40143210  2016-10-19T23:38:01Z      0
# 1264212  40143300  2016-10-19T23:48:09Z      0
# 1264213  40143340  2016-10-19T23:52:50Z      1
# 1264214  40143360  2016-10-19T23:55:24Z      0
# 1264215  40143380  2016-10-19T23:57:31Z      0
#
#                                                      Title  \
# 0        SQLStatement.execute() - multiple queries in o...
# 1        Good branching and merging tutorials for Torto...
# 2                                        ASP.NET Site Maps
# 3                       Function for creating color wheels
# 4        Adding scripting functionality to .NET applica...
# ...                                                    ...
# 1264211                           URL routing in PHP (MVC)
# 1264212           Bigquery.Jobs.Insert - Resumable Upload?
# 1264213                 Obfuscating code in android studio
# 1264214         How to fire function after v-model change?
# 1264215            npm run mocha test - files being cached
#
#                                                       Body
# 0        I've written database generation script SQL wa...
# 1        Are really good tutorials explaining branching...
# 2        Has anyone got experience creating SQL-based A...
# 3        This something I've pseudo-solved many times n...
# 4        I little game written C#. It uses database bac...
# ...                                                    ...
# 1264211  I building custom MVC project I base folder co...
# 1264212  The API docs show able make insert Jobs resuma...
# 1264213  Under minifyEnabled I changed false true. Then...
# 1264214  I input I use filter array objects Vue. I'm us...
# 1264215  I'm running mocha test I noticed changes refle...
#
# [1264216 rows x 5 columns]

# %% [markdown]
# #### on Answers.csv

# %%
df_answers['Answer_Body'] = df_answers['Answer_Body'].apply(lambda x: normalize_text(x))
df_answers['Answer_Body'] = df_answers['Answer_Body'].apply(lambda x: remove_stopwords_punctuations(x))
df_answers
# Out:
#                Id  Answer_Score  \
# 0              90            13
# 1              80            12
# 2             180             1
# 3             260             4
# 4             260            28
# ...           ...           ...
# 2014511  40143190             0
# 2014512  40137110             1
# 2014513  40141860             0
# 2014514  40077010             0
# 2014515  40142910             0
#
#                                                Answer_Body
# 0        Version Control Subversion A good resource sou...
# 1        I wound using this. It kind hack, actually wor...
# 2        I've read somewhere human eye can't distinguis...
# 3        Yes, I thought that, I soon figured another Do...
# 4        Oleg Shilo's C# Script solution (at The Code P...
# ...                                                    ...
# 2014511             Tanks SO answer I found answer myself:
# 2014512  tl;dr 19/10/16java.timeYou using troublesome o...
# 2014513  I came dirty workaround. Before bootstraping m...
# 2014514  I solved problem defining following function. ...
# 2014515                                    Try add method.
#
# [2014516 rows x 3 columns]

# %% [markdown]
# #### on Tags.csv

# %%
df_tags['Tag'] = df_tags['Tag'].apply(lambda x: str(x))
df_tags = concatenate_multiple_tags(df_tags)
df_tags
# Out:
#                Id                                             Tag
# 0              80                         flex,actionscript-3,air
# 1              90    svn,tortoisesvn,branch,branching-and-merging
# 2             120                             sql,asp.net,sitemap
# 3             180  algorithm,language-agnostic,colors,color-space
# 4             260         c#,.net,scripting,compiler-construction
# ...           ...                                             ...
# 1264211  40143210                                   php,.htaccess
# 1264212  40143300                                 google-bigquery
# 1264213  40143340                          android,android-studio
# 1264214  40143360                               javascript,vue.js
# 1264215  40143380                                 npm,mocha,babel
#
# [1264216 rows x 2 columns]

# %% [markdown]
# #### Merging dataframes

# %%
merged = pd.merge(df_questions, df_answers, how='inner', on="Id")

# %%
merged = pd.merge(merged, df_tags, how='inner', on="Id")

# %%
merged
# Out:
#                Id          CreationDate  Score  \
# 0              80  2008-08-01T13:57:07Z     26
# 1              80  2008-08-01T13:57:07Z     26
# 2              80  2008-08-01T13:57:07Z     26
# 3              90  2008-08-01T14:41:24Z    144
# 4              90  2008-08-01T14:41:24Z    144
# ...           ...                   ...    ...
# 2014511  40142910  2016-10-19T23:05:49Z      0
# 2014512  40142940  2016-10-19T23:08:42Z     -1
# 2014513  40142940  2016-10-19T23:08:42Z     -1
# 2014514  40143190  2016-10-19T23:36:01Z      1
# 2014515  40143190  2016-10-19T23:36:01Z      1
#
#                                                      Title  \
# 0        SQLStatement.execute() - multiple queries in o...
# 1        SQLStatement.execute() - multiple queries in o...
# 2        SQLStatement.execute() - multiple queries in o...
# 3        Good branching and merging tutorials for Torto...
# 4        Good branching and merging tutorials for Torto...
# ...                                                    ...
# 2014511  Validation for must_be_below_user_limit allowi...
# 2014512  Drawing an iscosceles triangle of asteriks on C++
# 2014513  Drawing an iscosceles triangle of asteriks on C++
# 2014514  How to execute multiline python code from a ba...
# 2014515  How to execute multiline python code from a ba...
#
#                                                       Body  Answer_Score  \
# 0        I've written database generation script SQL wa...            12
# 1        I've written database generation script SQL wa...             6
# 2        I've written database generation script SQL wa...             1
# 3        Are really good tutorials explaining branching...            13
# 4        Are really good tutorials explaining branching...             2
# ...                                                    ...           ...
# 2014511  So I Am building multi-tenant app Rails 4 Apar...             0
# 2014512  I learning c++ I'm trying draw iscosceles tria...             0
# 2014513  I learning c++ I'm trying draw iscosceles tria...             1
# 2014514  I need extend shell script (bash). As I much f...             5
# 2014515  I need extend shell script (bash). As I much f...             0
#
#                                                Answer_Body  \
# 0        I wound using this. It kind hack, actually wor...
# 1        The SQLite API function called something like ...
# 2        What making delimiter something little complex...
# 3        Version Control Subversion A good resource sou...
# 4        You also try Version Control Standalone Progra...
# ...                                                    ...
# 2014511                                    Try add method.
# 2014512  Here's it:Output:The basic idea switch mapping...
# 2014513  Alternative @space_voyager code support dynami...
# 2014514                                      Use here-doc:
# 2014515             Tanks SO answer I found answer myself:
#
#                                                   Tag
# 0                             flex,actionscript-3,air
# 1                             flex,actionscript-3,air
# 2                             flex,actionscript-3,air
# 3        svn,tortoisesvn,branch,branching-and-merging
# 4        svn,tortoisesvn,branch,branching-and-merging
# ...                                               ...
# 2014511      ruby-on-rails,validation,ruby-on-rails-4
# 2014512                                           c++
# 2014513                                           c++
# 2014514                         python,bash,multiline
# 2014515                         python,bash,multiline
#
# [2014516 rows x 8 columns]

# %%
merged = merged.astype("string")
merged[['Body', 'Tag']].fillna("", inplace = True)
# merged
# Out:
#                Id          CreationDate Score  \
# 0              80  2008-08-01T13:57:07Z    26
# 1              80  2008-08-01T13:57:07Z    26
# 2              80  2008-08-01T13:57:07Z    26
# 3              90  2008-08-01T14:41:24Z   144
# 4              90  2008-08-01T14:41:24Z   144
# ...           ...                   ...   ...
# 2014511  40142910  2016-10-19T23:05:49Z     0
# 2014512  40142940  2016-10-19T23:08:42Z    -1
# 2014513  40142940  2016-10-19T23:08:42Z    -1
# 2014514  40143190  2016-10-19T23:36:01Z     1
# 2014515  40143190  2016-10-19T23:36:01Z     1
#
#                                                      Title  \
# 0        SQLStatement.execute() - multiple queries in o...
# 1        SQLStatement.execute() - multiple queries in o...
# 2        SQLStatement.execute() - multiple queries in o...
# 3        Good branching and merging tutorials for Torto...
# 4        Good branching and merging tutorials for Torto...
# ...                                                    ...
# 2014511  Validation for must_be_below_user_limit allowi...
# 2014512  Drawing an iscosceles triangle of asteriks on C++
# 2014513  Drawing an iscosceles triangle of asteriks on C++
# 2014514  How to execute multiline python code from a ba...
# 2014515  How to execute multiline python code from a ba...
#
#                                                       Body Answer_Score  \
# 0        I've written database generation script SQL wa...           12
# 1        I've written database generation script SQL wa...            6
# 2        I've written database generation script SQL wa...            1
# 3        Are really good tutorials explaining branching...           13
# 4        Are really good tutorials explaining branching...            2
# ...                                                    ...          ...
# 2014511  So I Am building multi-tenant app Rails 4 Apar...            0
# 2014512  I learning c++ I'm trying draw iscosceles tria...            0
# 2014513  I learning c++ I'm trying draw iscosceles tria...            1
# 2014514  I need extend shell script (bash). As I much f...            5
# 2014515  I need extend shell script (bash). As I much f...            0
#
#                                                Answer_Body  \
# 0        I wound using this. It kind hack, actually wor...
# 1        The SQLite API function called something like ...
# 2        What making delimiter something little complex...
# 3        Version Control Subversion A good resource sou...
# 4        You also try Version Control Standalone Progra...
# ...                                                    ...
# 2014511                                    Try add method.
# 2014512  Here's it:Output:The basic idea switch mapping...
# 2014513  Alternative @space_voyager code support dynami...
# 2014514                                      Use here-doc:
# 2014515             Tanks SO answer I found answer myself:
#
#                                                   Tag
# 0                             flex,actionscript-3,air
# 1                             flex,actionscript-3,air
# 2                             flex,actionscript-3,air
# 3        svn,tortoisesvn,branch,branching-and-merging
# 4        svn,tortoisesvn,branch,branching-and-merging
# ...                                               ...
# 2014511      ruby-on-rails,validation,ruby-on-rails-4
# 2014512                                           c++
# 2014513                                           c++
# 2014514                         python,bash,multiline
# 2014515                         python,bash,multiline
#
# [2014516 rows x 8 columns]

# %%
merged.to_csv("questions_answers_tags.csv", index = False, encoding = 'latin1')
